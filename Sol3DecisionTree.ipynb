# %% [markdown]
# # Importing Libraries and Reading data.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style
style.use("dark_background")
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
import seaborn as sb

# %%
data = pd.read_csv("C:/Users/Animkush/Desktop/Practice/data/irisrmc.csv")

# %%
#data.head(5)
data = data.drop(["Id"], axis=1) # id column doesn't contribute anytihng to our data so we remove it.
data.head(5)
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# # Visualizing the data.

# %%
iris = sb.load_dataset("iris")
iris_g = sb.PairGrid(iris, hue="species")
iris_g.map_diag(plt.hist)
iris_g.map_offdiag(plt.scatter)

# %%
#creating labels and features.
X = data.drop(["Species"], axis=1)
y = data["Species"]

# %% [markdown]
# # Fitting the Data Features and Label into DecisionTreeClassifier

# %%
dtree = DecisionTreeClassifier()
dtree.fit(X, y)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# # Textual representation of Decision Tree after fitting the model.

# %%
text_rep= tree.export_text(dtree)
print(text_rep)
# Out:
# |--- feature_3 <= 0.80
# |   |--- class: Iris-setosa
# |--- feature_3 >  0.80
# |   |--- feature_3 <= 1.75
# |   |   |--- feature_2 <= 4.95
# |   |   |   |--- feature_3 <= 1.65
# |   |   |   |   |--- class: Iris-versicolor
# |   |   |   |--- feature_3 >  1.65
# |   |   |   |   |--- class: Iris-virginica
# |   |   |--- feature_2 >  4.95
# |   |   |   |--- feature_3 <= 1.55
# |   |   |   |   |--- class: Iris-virginica
# |   |   |   |--- feature_3 >  1.55
# |   |   |   |   |--- feature_0 <= 6.95
# |   |   |   |   |   |--- class: Iris-versicolor
# |   |   |   |   |--- feature_0 >  6.95
# |   |   |   |   |   |--- class: Iris-virginica
# |   |--- feature_3 >  1.75
# |   |   |--- feature_2 <= 4.85
# |   |   |   |--- feature_0 <= 5.95
# |   |   |   |   |--- class: Iris-versicolor
# |   |   |   |--- feature_0 >  5.95
# |   |   |   |   |--- class: Iris-virginica
# |   |   |--- feature_2 >  4.85
# |   |   |   |--- class: Iris-virginica

# %% [markdown]
# # Graphical Representation

# %%
plt.rcParams.update({
    "text.color": "black"})
fig = plt.figure(figsize=(30,20))
_ = tree.plot_tree(dtree, feature_names=X.columns, filled=True, rounded=True)

# %% [markdown]
# # Conclusion

# %% [markdown]
# We are sucessfully able to make our decision tree classifier, we can further provide this model with new dataset and let it predict the class.
